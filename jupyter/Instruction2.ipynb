# %%
import pandas as pd

# %% [markdown]
# heading

# %% [markdown]
# $x^3$ + $x^2$

# %% [markdown]
# Instruction to use jupyter

# %% [markdown]
# $$
# \frac{f(x)}{g(x)}\\
# x^4\\
# A_i\\
# B_{ij}\\
# \sqrt[n]{f(x)}
# \sqrt[3]{g(x)}\\
# \sqrt[n]{f(x)}\\
# \sqrt[3]{g(x)}
# $$

# %% [markdown]
# -List 1

# %% [markdown]
# -list1
