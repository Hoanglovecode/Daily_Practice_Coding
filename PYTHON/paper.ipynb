# %%
print("Hoangdepzaiii")
# Out:
# Hoangdepzaiii

# %% [markdown]
# Shift + Enter	Chạy cell và xuống cell tiếp
# Ctrl + Enter	Chạy cell nhưng ở lại cell
# Alt + Enter	Chạy cell và tạo cell mới
# B	Tạo cell bên dưới
# A	Tạo cell phía trên
# DD	Xóa cell
# M	Chuyển cell → Markdown
# Y	Markdown → Code
# Enter	Vào chế độ viết code
# Esc	Vào chế độ phím tắt
# H	Xem tất cả phím tắt
# Ctrl + F	Tìm trong notebook
